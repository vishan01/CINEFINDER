# %%
import pandas as pd
from collections import defaultdict
from itertools import chain

# %%
data=pd.read_csv("../data/Final_data.csv")
data
# Out:
#         Unnamed: 0.1  Unnamed: 0      id  \
# 0                  0           0  615656
# 1                  1           1  758323
# 2                  2           2  667538
# 3                  3           3  640146
# 4                  4           4  677179
# ...              ...         ...     ...
# 688119        688119      722495  505944
# 688120        688120      722497  379615
# 688121        688121      722498  957818
# 688122        688122      722499  179422
# 688123        688123      722500  968161
#
#                                          title  \
# 0                            Meg 2: The Trench
# 1                          The Pope's Exorcist
# 2             Transformers: Rise of the Beasts
# 3            Ant-Man and the Wasp: Quantumania
# 4                                    Creed III
# ...                                        ...
# 688119                         Key telugu 2011
# 688120  ROH: Survival of The Fittest - Night 2
# ...

# %%
data.dtypes
# Out:
# Unnamed: 0.1              int64
# Unnamed: 0                int64
# id                        int64
# title                    object
# genres                   object
# original_language        object
# overview                 object
# popularity              float64
# production_companies     object
# release_date             object
# budget                  float64
# revenue                 float64
# runtime                 float64
# status                   object
# tagline                  object
# vote_average            float64
# vote_count              float64
# credits                  object
# keywords                 object
# poster_path              object
# backdrop_path            object
# recommendations          object
# result                    int64
# dtype: object

# %%
actors = data["credits"].values
actors=list(actors)
actors = [str(i).split("-") for i in actors]
actors=list(chain.from_iterable(actors))
len(actors)
# Out:
# 4991799

# %%
actors_set=set(actors)
len(actors_set)
# Out:
# 1166948

# %%
actors_list = list(actors_set)
# Out:
# 634914

# %%
hm = defaultdict(list)
for i,row in data.iterrows():
    x=str(row["credits"]).split("-")
    for j in x:
        hm[j].append(row["id"])
hm
# Out:
# defaultdict(list,
#             {'Jason Statham': [615656,
#               385687,
#               299054,
#               866398,
#               739405,
#               384018,
#               637649,
#               337339,
#               168259,
#               15092,
#               385128,
#               345940,
#               755679,
#               27578,
#               138103,
#               204082,
#               10483,
#               1948,
#               72387,
#               76163,
#               9335,
#               278924,
#               55846,
#               265208,
#               4108,
#               136418,
#               13387,
#               10431,
#               1538,
#               8848,
#               27582,
#               107,
#               9759,
#               119283,
#               238713,
#               45772,
#               9654,
#               49021,
#               12096,
#               10796,
#               2312,
# ...
