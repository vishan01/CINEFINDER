# %%
# !pip install -q opendatasets
# !pip install -U scikit-learn
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.1/12.1 MB 39.3 MB/s eta 0:00:00
# ...
#   Attempting uninstall: scikit-learn
#     Found existing installation: scikit-learn 1.2.2
#     Uninstalling scikit-learn-1.2.2:
#       Successfully uninstalled scikit-learn-1.2.2
# ...

# %%
import opendatasets as od
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
od.download('https://www.kaggle.com/datasets/akshaypawar7/millions-of-movies')
data = pd.read_csv("/content/millions-of-movies/movies.csv")
data
# Out:
# Please provide your Kaggle credentials to download this dataset. Learn more: http://bit.ly/kaggle-creds
# Your Kaggle username: vishan1
# Your Kaggle Key: ··········
# ...
# 100%|██████████| 164M/164M [00:01<00:00, 101MB/s]
#             id                              title  \
# 0       615656                  Meg 2: The Trench
# 1       758323                The Pope's Exorcist
# 2       667538   Transformers: Rise of the Beasts
# 3       640146  Ant-Man and the Wasp: Quantumania
# 4       677179                          Creed III
# ...        ...                                ...
# 722505  705357        Six Photographs: René Burri
# 722506  481470           Vietnam: The Last Battle
# 722507  397991                         Where When
# 722508  859404                               Solo
# 722509  968161                      Gising Sining
#
#                                   genres original_language  \
# 0          Action-Science Fiction-Horror                en
# ...

# %%
def check_result(a,b):
  c= a/b
  data["result"]= c

def value_series(c):
    if(c>=2):
      return "Blockbuster"
    if(c>=1.5):
      return "Super Hit"
    if(c>=1):
      return "Hit"
    if(c>=0.5):
      return "flop"
    if(c==0.0):
      return "Data Unavailable"
    if(c<0.5):
      return "disaster"
    else:
      return "NAN"
check_result(data["revenue"],data["budget"])
data["result"]=data["result"].apply(value_series)

# %%
data_unavailable = data[np.logical_or(data["result"]=="Data Unavailable",data["result"]=="NAN")]
data_unavailable
# Out:
#             id                        title                            genres  \
# 9       956101            The Eighth Clause                          Thriller
# 11      447277           The Little Mermaid  Adventure-Family-Fantasy-Romance
# 16      965839          Lord of the Streets                            Action
# 18      772515      Huesera: The Bone Woman              Drama-Horror-Mystery
# 19      619930                       Narvik          War-Drama-History-Action
# ...        ...                          ...                               ...
# 722505  705357  Six Photographs: René Burri                       Documentary
# 722506  481470     Vietnam: The Last Battle                       Documentary
# 722507  397991                   Where When                               NaN
# 722508  859404                         Solo                               NaN
# 722509  968161                Gising Sining                               NaN
#
# ...

# %%
data_train = data[np.logical_and(data["result"]!="Data Unavailable",data["result"]!="NAN")]
data_train
data_train.to_csv("Train_data.csv")

# %%
data_telugu=data_train[data_train["original_language"]=="te"]
data_telugu[data_telugu["result"]=="disaster"]
# Out:
#             id          title                     genres original_language  \
# 98463   280363     Aditya 369  Science Fiction-Adventure                te
# 231833  279449  Gopala Gopala     Comedy-Romance-Fantasy                te
# 579716  917437      ప్రేమాలయం                        NaN                te
#
#                                                  overview  popularity  \
# 98463   Aditya 369 is a time machine invented by an ab...       1.960
# 231833  Gopala Rao an atheist finds himself in the mid...       0.958
# 579716                                                NaN       0.600
#
#                               production_companies release_date     budget  \
# 98463                                 Sridevi Arts   1991-08-18  1200000.0
# 231833  Suresh Productions-Northstar Entertainment   2015-01-10      500.0
# 579716                                         NaN          NaN      821.0
#
#          revenue  ...    status tagline vote_average  vote_count  \
# ...
