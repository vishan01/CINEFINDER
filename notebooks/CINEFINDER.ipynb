# %%
# !pip install -q opendatasets

# %% [markdown]
# **Lets View the Database**

# %%
import opendatasets as od
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
od.download('https://www.kaggle.com/datasets/akshaypawar7/millions-of-movies')
data = pd.read_csv("/content/millions-of-movies/movies.csv")
data
# Out:
# Skipping, found downloaded files in "./millions-of-movies" (use force=True to force download)
#             id                                        title  \
# 0       615656                            Meg 2: The Trench
# 1       758323                          The Pope's Exorcist
# 2       667538             Transformers: Rise of the Beasts
# 3       640146            Ant-Man and the Wasp: Quantumania
# 4       677179                                    Creed III
# ...        ...                                          ...
# 722509  962463  The Trobriand Islanders of Papua New Guinea
# 722510  719564                                       Cuilos
# 722511  951588                   Bollyrobics: Dance Workout
# 722512  874303         Sloppy Jo and The Heartbreak Company
# 722513  968161                                Gising Sining
#
#                                   genres original_language  \
# 0          Action-Science Fiction-Horror                en
# 1                Horror-Mystery-Thriller                en
# 2       Action-Adventure-Science Fiction                en
# 3       Action-Adventure-Science Fiction                en
# 4                           Drama-Action                en
# ...                                  ...               ...
# 722509                       Documentary                en
# 722510                               NaN                es
# 722511                               NaN                en
# 722512                            Action                ja
# 722513                               NaN                tl
#
#                                                  overview  popularity  \
# 0       An exploratory dive into the deepest depths of...    8763.998
# 1       Father Gabriele Amorth Chief Exorcist of the V...    5953.227
# 2       When a new threat capable of destroying the en...    5409.104
# 3       Super-Hero partners Scott Lang and Hope van Dy...    4425.387
# 4       After dominating the boxing world Adonis Creed...    3994.342
# ...                                                   ...         ...
# 722509  The Trobriand Islands lie off the eastern tip ...       0.600
# 722510  Michelle is about to bring her boyfriend home ...       0.600
# 722511  Indian dance elements from well known bollywoo...       0.600
# 722512  Japanese V-Cinema film that sought to emulate ...       0.600
# 722513  In a country where fascism foolishness of peop...       0.600
#
#                                      production_companies release_date  \
# 0       Apelles Entertainment-Warner Bros. Pictures-di...   2023-08-02
# 1       Screen Gems-2.0 Entertainment-Jesus & Mary-Wor...   2023-04-05
# 2       Skydance-Paramount-di Bonaventura Pictures-Bay...   2023-06-06
# 3                  Marvel Studios-Kevin Feige Productions   2023-02-15
# 4       Metro-Goldwyn-Mayer-Proximity Media-Balboa Pro...   2023-03-01
# ...                                                   ...          ...
# 722509                                                NaN   1990-01-01
# 722510                 Temporal Films-Les Films du Requin   2008-06-05
# 722511                                                NaN   2007-09-11
# 722512                                                NaN   1992-06-26
# 722513                                          Studio RD          NaN
#
#              budget      revenue  runtime    status  \
# 0       129000000.0  352056482.0    116.0  Released
# 1        18000000.0   65675816.0    103.0  Released
# 2       200000000.0  407045464.0    127.0  Released
# 3       200000000.0  475766228.0    125.0  Released
# 4        75000000.0  269000000.0    116.0  Released
# ...             ...          ...      ...       ...
# 722509          0.0          0.0     52.0  Released
# 722510          0.0          0.0     12.0  Released
# 722511          0.0          0.0    103.0  Released
# 722512          0.0          0.0     80.0  Released
# 722513          0.0          0.0     19.0  Released
#
#                                                   tagline  vote_average  \
# 0                                       Back for seconds.         7.079
# 1       Inspired by the actual files of Father Gabriel...         7.433
# 2                                          Unite or fall.         7.340
# 3                 Witness the beginning of a new dynasty.         6.507
# 4                           You can't run from your past.         7.262
# ...                                                   ...           ...
# 722509                                                NaN         0.000
# 722510                                                NaN         0.000
# 722511                                                NaN         0.000
# 722512                                                NaN         0.000
# 722513                                                NaN         0.000
#
#         vote_count                                            credits  \
# 0           1365.0  Jason Statham-Wu Jing-Shuya Sophia Cai-Sergio ...
# 1            545.0  Russell Crowe-Daniel Zovatto-Alex Essoe-Franco...
# 2           1007.0  Anthony Ramos-Dominique Fishback-Luna Lauren V...
# 3           2811.0  Paul Rudd-Evangeline Lilly-Jonathan Majors-Kat...
# 4           1129.0  Michael B. Jordan-Tessa Thompson-Jonathan Majo...
# ...            ...                                                ...
# 722509         0.0                                                NaN
# 722510         0.0  Monserrat Fernández-Michelle Vazquez-Grettel Q...
# 722511         0.0                                                NaN
# 722512         0.0  Riki Takeuchi-Mie Yoshida-Yumiko Itaya-Keishi ...
# 722513         0.0                               Ruka Azuma-Mel Perez
#
#                                                  keywords  \
# 0                     based on novel or book-sequel-kaiju
# 1       spain-rome italy-vatican-pope-pig-possession-c...
# 2       peru-alien-end of the world-based on cartoon-b...
# 3       hero-ant-sequel-superhero-based on comic-famil...
# 4       philadelphia pennsylvania-husband wife relatio...
# ...                                                   ...
# 722509                                                NaN
# 722510                                                NaN
# 722511                                                NaN
# 722512                                           v-cinema
# 722513                                                NaN
#
#                              poster_path                     backdrop_path  \
# 0       /4m1Au3YkjqsxF8iwQy0fPYSxE0h.jpg  /qlxy8yo5bcgUw2KAmmojUKp4rHd.jpg
# 1       /9JBEPLTPSm0d1mbEcLxULjJq9Eh.jpg  /hiHGRbyTcbZoLsYYkO4QiCLYe34.jpg
# 2       /gPbM0MK8CP8A174rmUwGsADNYKD.jpg  /woJbg7ZqidhpvqFGGMRhWQNoxwa.jpg
# 3       /qnqGbB22YJ7dSs4o6M7exTpNxPz.jpg  /m8JTwHFwX7I7JY5fPe4SjqejWag.jpg
# 4       /cvsXj3I9Q2iyyIo95AecSd1tad7.jpg  /5i6SjyDbDWqyun8klUuCxrlFbyw.jpg
# ...                                  ...                               ...
# 722509                               NaN                               NaN
# 722510  /tHbhRLFea3BecWlCrAlEWlwEWy6.jpg                               NaN
# 722511  /pqaVLRu5V5WoJAT82RkxMKZ65Yw.jpg                               NaN
# 722512  /zJkgSNOd57iq7uUwCvvmacY0bXy.jpg                               NaN
# 722513   /jv34KgS7D997H5kbVYxKLJRScg.jpg                               NaN
#
#                                           recommendations
# 0       1006462-298618-569094-1061181-346698-1076487-6...
# 1       713704-296271-502356-1076605-1084225-1008005-9...
# 2       496450-569094-298618-385687-877100-598331-4628...
# 3       823999-676841-868759-734048-267805-965839-1033...
# 4       965839-267805-943822-842942-1035806-823999-107...
# ...                                                   ...
# 722509                                                NaN
# 722510                                                NaN
# 722511                                                NaN
# 722512                                                NaN
# 722513                                                NaN
#
# [722514 rows x 20 columns]

# %% [markdown]
# **Checking the results of the Movie**

# %%
def check_result(a,b):
  c= a/b
  data["result"]= c

def value_series(c):
    if(c>=2):
      return "Blockbuster"
    if(c>=1.5):
      return "Super Hit"
    if(c>=1):
      return "Hit"
    if(c>=0.5):
      return "flop"
    if(c==0.0):
      return "Data Unavailable"
    if(c<0.5):
      return "disaster"
check_result(data["revenue"],data["budget"])
data["result"]=data["result"].apply(value_series)

# %% [markdown]
# **Visualize The Results**

# %%
sns.plotting_context("talk")

sns.countplot(data=data,y="result",palette="husl",hue="result",legend=True,order=("Data Unavailable","Blockbuster","Super Hit","Hit","flop","disaster"))
# Out:
# <Axes: xlabel='count', ylabel='result'>

# %% [markdown]
# **There are lot of values whose result is unavailable**

# %% [markdown]
# **Lets check the values whose data is unavailable**

# %%
data_unavailable = data[data["result"]=="Data Unavailable"]
data_unavailable
# Out:
#             id                                              title  \
# 10      447277                                 The Little Mermaid
# 15      965839                                Lord of the Streets
# 18      619930                                             Narvik
# 27      848326             Rebel Moon - Part One: A Child of Fire
# 38      565770                                        Blue Beetle
# ...        ...                                                ...
# 722302  777932                                      Hall Monitors
# 722318  852383  Senta a púa operation - betrayal on the high c...
# 722340  966004                                    Pro Tei, For Me
# 722420  758189                                  The Wiccan Trials
# 722481  951080                                         Bus Driver
#
#                                   genres original_language  \
# 10      Adventure-Family-Fantasy-Romance                en
# 15                                Action                en
# 18              War-Drama-History-Action                no
# 27      Science Fiction-Action-Adventure                en
# 38                Action-Science Fiction                en
# ...                                  ...               ...
# 722302                               NaN                en
# 722318                            Action                en
# 722340                       War-Mystery                pt
# 722420                               NaN                en
# 722481                               NaN                en
#
#                                                  overview  popularity  \
# 10      The youngest of King Triton’s daughters and th...    2118.742
# 15      When Jason Dyson refuses to make his prized fi...    1691.825
# 18      April 1940. The eyes of the world are on Narvi...    1383.465
# 27      When a peaceful colony on the edge of the gala...     923.889
# 38      Recent college grad Jaime Reyes returns home f...     717.798
# ...                                                   ...         ...
# 722302  Booker an overzealous Hall Monitor with hopes ...       0.600
# 722318  A group of drug dealers located in the outskir...       0.600
# 722340  Images of ruin and destruction mirror the sky....       0.600
# 722420  A young woman who believes she has powers open...       0.600
# 722481  The normal journey of a London bus driver tran...       0.600
#
#                                      production_companies release_date  \
# 10      Walt Disney Pictures-Lucamar Productions-Marc ...   2023-05-18
# 15                                           Mutiny Films   2022-04-22
# 18                                    Nordisk Film Norway   2022-12-25
# 27                        The Stone Quarry-Grand Electric   2023-12-15
# 38      Warner Bros. Pictures-The Safran Company-DC Films   2023-08-16
# ...                                                   ...          ...
# 722302                                                NaN   2019-05-21
# 722318                                       fredy videos   2019-04-05
# 722340                                                NaN          NaN
# 722420                                                NaN   2018-10-18
# 722481                                                NaN          NaN
#
#              budget  revenue  ...    status  \
# 10      250000000.0      0.0  ...  Released
# 15        1000000.0      0.0  ...  Released
# 18        8000000.0      0.0  ...  Released
# 27       83000000.0      0.0  ...  Released
# 38      120000000.0      0.0  ...  Released
# ...             ...      ...  ...       ...
# 722302        100.0      0.0  ...  Released
# 722318       2000.0      0.0  ...  Released
# 722340         10.0      0.0  ...  Released
# 722420       2500.0      0.0  ...  Released
# 722481      39500.0      0.0  ...  Released
#
#                                                   tagline vote_average  \
# 10      Watch and you'll see, some day I'll be, part o...        5.957
# 15                                                    NaN        4.900
# 18                                  Hitler's First Defeat        7.000
# 27                      There are no heroes. Only rebels.        6.453
# 38      Jaime Reyes is a superhero whether he likes it...        7.464
# ...                                                   ...          ...
# 722302  Being a Hall Monitor is more than just an Elec...        0.000
# 722318  Senta a púa operation - betrayal on the high c...        0.000
# 722340                     There is a Desert in Formation        0.000
# 722420                                                NaN        0.000
# 722481                                                NaN        0.000
#
#         vote_count                                            credits  \
# 10           220.0  Halle Bailey-Jonah Hauer-King-Daveed Diggs-Awk...
# 15            29.0  Treach-Quinton Jackson-Khalil Rountree Jr.-And...
# 18           195.0  Kristine Cornelie M. Hartgen-Carl Martin Egges...
# 27           414.0  Sofia Boutella-Djimon Hounsou-Ed Skrein-Michie...
# 38            69.0  Xolo Mariduena-Bruna Marquezine-Adriana Barraz...
# ...            ...                                                ...
# 722302         0.0  Ian Sheldahl-Brett MacKay-Jonovan Castaneda-Le...
# 722318         0.0                                                NaN
# 722340         0.0                                                NaN
# 722420         0.0  Carrie Vu-James Cribbins-Jon Peterson-Estherik...
# 722481         0.0                  Bally Gill-John Ramm-Sarah Vevers
#
#                                                  keywords  \
# 10      musical-mermaid-based on fairy tale-live actio...
# 15                                                    NaN
# 18      winter-world war ii-based on true story-bombin...
# 27      space war-space-space opera-space adventure-ac...
# 38      armor-superhero-family-high tech-origin-alien ...
# ...                                                   ...
# 722302                                                NaN
# 722318                                war hero-second war
# 722340                                                NaN
# 722420                                                NaN
# 722481                                                NaN
#
#                              poster_path                     backdrop_path  \
# 10      /ym1dxyOk4jFcSl4Q2zmRrA5BEEN.jpg  /hJoMSAltRx5xvlAXvKyDdugjucJ.jpg
# 15      /n9YWVQRc0zw0nwrFcOkOpffZxjc.jpg  /g8Yytnby0hIPft5l56mgJtZyR1k.jpg
# 18      /gU4mmINWUF294Wzi8mqRvi6peMe.jpg  /ogFIG0fNXEYRQKrpnoRJcXQNX9n.jpg
# 27      /ui4DrH1cKk2vkHshcUcGt2lKxCm.jpg  /sRLC052ieEzkQs9dEtPMfFxYkej.jpg
# 38      /gvtMN1IWBqqPYYlPy2saWaPbmP9.jpg   /H6j5smdpRqP9a8UnhWp6zfl0SC.jpg
# ...                                  ...                               ...
# 722302  /s6xXGnA0sfy8sCPbJ1JfyzYwtkq.jpg                               NaN
# 722318                               NaN                               NaN
# 722340  /lXtDvNwE8tPK3qNPFBttNUHrWg2.jpg  /uWdfwJhA0fGFkgA4riuHksKieEv.jpg
# 722420  /foc97PIV8TyrsvcCT0APEu4F7cc.jpg                               NaN
# 722481  /key5OeVU44etbJZtmMFLAOMMQog.jpg                               NaN
#
#                                           recommendations            result
# 10      420808-798286-447365-493529-502356-594767-6401...  Data Unavailable
# 15                                                 982467  Data Unavailable
# 18      458737-800815-414268-843794-606154-619687-7476...  Data Unavailable
# 27                                                    NaN  Data Unavailable
# 38      346698-791343-637663-1003581-41988-791348-8725...  Data Unavailable
# ...                                                   ...               ...
# 722302                                                NaN  Data Unavailable
# 722318                                                NaN  Data Unavailable
# 722340                                                NaN  Data Unavailable
# 722420                                                NaN  Data Unavailable
# 722481                                                NaN  Data Unavailable
#
# [25485 rows x 21 columns]
